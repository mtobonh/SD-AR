# %%
# %%capture
# !pip install mne #The MNE Package is installed
FILEID = "1-bPsREsUCOiJHzIqi8DQrfSjTAf5VAW_"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O MI_EEG_ClassMeth.zip && rm -rf /tmp/cookies.txt
# !unzip MI_EEG_ClassMeth.zip #Package with useful functions for motor imagery classification based in EEG.
# !dir

# %% [markdown]
# #Import

# %%
from google.colab.drive import mount
import numpy as np
import os
from time import time
from MI_EEG_ClassMeth.FeatExtraction import Power_based_Connectivities, Phase_based_Connectivities, MotifSynchronization
from MI_EEG_ClassMeth.Preprocessing import Flatten
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedShuffleSplit, GridSearchCV
from MI_EEG_ClassMeth.utils import grid_search_info
from pickle import dump as pdump
from joblib import dump as jdump

# %% [markdown]
# #Mount Drive

# %%
mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Power Based Connectivities

# %%
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/pearson/none_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/pearson/ica_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/pearson/none_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/pearson/ica_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/spearman/none_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/spearman/ica_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/spearman/none_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/spearman/ica_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/gfc/none_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/gfc/ica_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/gfc/none_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/gfc/ica_sl/')

os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/pearson/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/spearman/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/gfc/')

# %%
data_dir = '/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/data/'
models_dir = '/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/'
results_dir = '/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/'

seed = 23

subjects = np.arange(9) + 1

pbc = Power_based_Connectivities()
flatt = Flatten()

clf = LDA(solver='lsqr', shrinkage='auto')

hyparams = {}

k = 10
test_size=0.2
cv = StratifiedShuffleSplit(n_splits=k, test_size=test_size, random_state=seed)

grid_search = GridSearchCV(clf, hyparams, cv=cv, verbose=0, scoring='accuracy',
                          refit=True, error_score='raise', n_jobs=-1, return_train_score=True)

# ------------------------------------------------------------------------------
t_i = time()
for sbj in subjects:
  y_dir = os.path.join(data_dir , 'labels/training/')
  y = np.load(y_dir + 'sbj' + str(sbj) + '.npy')

  for type_con in ['pearson', 'spearman', 'gfc']:
    cv_results = {'params':[], 'mean_train_acc':[], 'std_train_acc':[], 'mean_test_acc':[], 'std_test_acc':[]}

    for ica in ['none_', 'ica_']:
      for sl in ['none', 'sl']:       
        X = np.load(data_dir + ica+sl + '/' + 'training/' + 'sbj' + str(sbj) + '.npy')
        C_xx_w_f = pbc.transform(X, type_con=type_con, gammad=1)
        flat_C_xx_w_f = flatt.transform(C_xx_w_f)

        grid_search.fit(flat_C_xx_w_f, y)
        best_params, (mean_test, std_test), (mean_train, std_train), _, _  = grid_search_info(grid_search.cv_results_, ['score'])
        cv_results['params'].append((ica, sl) + tuple(best_params.values()))
        cv_results['mean_train_acc'].append(round(mean_train[0]*100, 1))
        cv_results['std_train_acc'].append(round(std_train[0]*100, 1))
        cv_results['mean_test_acc'].append(round(mean_test[0]*100, 1))
        cv_results['std_test_acc'].append(round(std_test[0]*100, 1))

        jdump(grid_search.best_estimator_, models_dir + type_con + '/' + ica+sl + '/'+ 'sbj' + str(sbj) + '.joblib')
    
    with open(results_dir + type_con + '/' + 'sbj' + str(sbj) + '.txt', 'wb') as f:
      pdump(cv_results, f)

t_f = time() - t_i
print('time:',round(t_f/60, 2),'m')
# Out:
# time: 14.18 m

# %% [markdown]
# #Phase Based Connectivities

# %%
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/coh/none_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/coh/ica_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/coh/none_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/coh/ica_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/plv/none_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/plv/ica_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/plv/none_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/plv/ica_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/pli/none_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/pli/ica_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/pli/none_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/pli/ica_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/wpli/none_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/wpli/ica_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/wpli/none_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/wpli/ica_sl/')

os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/coh/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/plv/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/pli/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/wpli/')

# %%
data_dir = '/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/data/'
models_dir = '/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/'
results_dir = '/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/'

seed = 23

subjects = np.arange(9) + 1

pbc = Phase_based_Connectivities()
flatt = Flatten()

clf = LDA(solver='lsqr', shrinkage='auto')

hyparams = {}

k = 10
test_size=0.2
cv = StratifiedShuffleSplit(n_splits=k, test_size=test_size, random_state=seed)

grid_search = GridSearchCV(clf, hyparams, cv=cv, verbose=0, scoring='accuracy',
                          refit=True, error_score='raise', n_jobs=-1, return_train_score=True)

# ------------------------------------------------------------------------------
t_i = time()
for sbj in subjects:
  y_dir = os.path.join(data_dir , 'labels/training/')
  y = np.load(y_dir + 'sbj' + str(sbj) + '.npy')

  for type_con in ['coh', 'plv', 'pli', 'wpli']:
    cv_results = {'params':[], 'mean_train_acc':[], 'std_train_acc':[], 'mean_test_acc':[], 'std_test_acc':[]}

    for ica in ['none_', 'ica_']:
      for sl in ['none', 'sl']:       
        X = np.load(data_dir + ica+sl + '/' + 'training/' + 'sbj' + str(sbj) + '.npy')
        C_xx_w_f = pbc.transform(X, type_con=type_con)
        flat_C_xx_w_f = flatt.transform(C_xx_w_f)

        grid_search.fit(flat_C_xx_w_f, y)
        best_params, (mean_test, std_test), (mean_train, std_train), _, _  = grid_search_info(grid_search.cv_results_, ['score'])
        cv_results['params'].append((ica, sl) + tuple(best_params.values()))
        cv_results['mean_train_acc'].append(round(mean_train[0]*100, 1))
        cv_results['std_train_acc'].append(round(std_train[0]*100, 1))
        cv_results['mean_test_acc'].append(round(mean_test[0]*100, 1))
        cv_results['std_test_acc'].append(round(std_test[0]*100, 1))

        jdump(grid_search.best_estimator_, models_dir + type_con + '/' + ica+sl + '/'+ 'sbj' + str(sbj) + '.joblib')
    
    with open(results_dir + type_con + '/' + 'sbj' + str(sbj) + '.txt', 'wb') as f:
      pdump(cv_results, f)

t_f = time() - t_i
print('time:',round(t_f/60, 2),'m')
# Out:
# time: 40.45 m

# %% [markdown]
# #Information Based Connectivities

# %%
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/motif/none_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/motif/ica_none/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/motif/none_sl/')
os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/motif/ica_sl/')

os.makedirs('/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/motif/')

# %%
data_dir = '/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/data/'
models_dir = '/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/models/'
results_dir = '/content/drive/Shareddrives/GCPDS/users/Mateo/BCICIV2a_preprocessing/results/hyparam_tuning/'

seed = 23

subjects = np.arange(9) + 1

mt = MotifSynchronization()
flatt = Flatten()

clf = LDA(solver='lsqr', shrinkage='auto')

hyparams = {}

k = 10
test_size=0.2
cv = StratifiedShuffleSplit(n_splits=k, test_size=test_size, random_state=seed)

grid_search = GridSearchCV(clf, hyparams, cv=cv, verbose=0, scoring='accuracy',
                          refit=True, error_score='raise', n_jobs=-1, return_train_score=True)

# ------------------------------------------------------------------------------
t_i = time()
for sbj in subjects:
  y_dir = os.path.join(data_dir , 'labels/training/')
  y = np.load(y_dir + 'sbj' + str(sbj) + '.npy')

  for type_con in ['motif']:
    cv_results = {'params':[], 'mean_train_acc':[], 'std_train_acc':[], 'mean_test_acc':[], 'std_test_acc':[]}

    for ica in ['none_', 'ica_']:
      for sl in ['none', 'sl']:       
        X = np.load(data_dir + ica+sl + '/' + 'training/' + 'sbj' + str(sbj) + '.npy')
        C_xx_w_f = mt.transform(X)
        flat_C_xx_w_f = flatt.transform(C_xx_w_f)

        grid_search.fit(flat_C_xx_w_f, y)
        best_params, (mean_test, std_test), (mean_train, std_train), _, _  = grid_search_info(grid_search.cv_results_, ['score'])
        cv_results['params'].append((ica, sl) + tuple(best_params.values()))
        cv_results['mean_train_acc'].append(round(mean_train[0]*100, 1))
        cv_results['std_train_acc'].append(round(std_train[0]*100, 1))
        cv_results['mean_test_acc'].append(round(mean_test[0]*100, 1))
        cv_results['std_test_acc'].append(round(std_test[0]*100, 1))

        jdump(grid_search.best_estimator_, models_dir + type_con + '/' + ica+sl + '/'+ 'sbj' + str(sbj) + '.joblib')
    
    with open(results_dir + type_con + '/' + 'sbj' + str(sbj) + '.txt', 'wb') as f:
      pdump(cv_results, f)

t_f = time() - t_i
print('time:',round(t_f/60, 2),'m')
# Out:
# time: 6.92 m
